# %% [markdown]
# **1)Cargo mi DATA**

# %%
import pandas as pd
df=pd.read_excel('https://github.com/CamilaBracamonte/PC2.1/blob/main/HDI%20(4).xlsx?raw=true',header=4)
df
# Out:
#     Unnamed: 0                                         Unnamed: 1  \
# 0     HDI rank                                            Country
# 1          NaN                                                NaN
# 2          NaN                        VERY HIGH HUMAN DEVELOPMENT
# 3            1                                        Switzerland
# 4            2                                             Norway
# ..         ...                                                ...
# 267        NaN                          Column 2: UNDESA (2022a).
# 268        NaN  Column 3: CEDLAS and World Bank (2022), ICF Ma...
# 269        NaN  Column 4: Barro and Lee (2018), ICF Macro Demo...
# 270        NaN  Column 5: IMF (2022), UNDESA (2022b), United N...
# 271        NaN  Column 6: Calculated based on data in columns ...
#
#     Human Development Index (HDI)   Unnamed: 3 Life expectancy at birth  \
# 0                            Value         NaN                  (years)
# ...

# %% [markdown]
# 2)

# %%
cols_to_keep = df.columns[:2] #Eliminacion de columnas que tienen nombres NaN en su primera fila, excepto las 2 primeras

df_nuevo = pd.concat([df[cols_to_keep], df.loc[:, df.iloc[0].notna()].iloc[:, 2:]], axis=1)
df_nuevo
# Out:
#     Unnamed: 0                                         Unnamed: 1  \
# 0     HDI rank                                            Country
# 1          NaN                                                NaN
# 2          NaN                        VERY HIGH HUMAN DEVELOPMENT
# 3            1                                        Switzerland
# 4            2                                             Norway
# ..         ...                                                ...
# 267        NaN                          Column 2: UNDESA (2022a).
# 268        NaN  Column 3: CEDLAS and World Bank (2022), ICF Ma...
# 269        NaN  Column 4: Barro and Lee (2018), ICF Macro Demo...
# 270        NaN  Column 5: IMF (2022), UNDESA (2022b), United N...
# 271        NaN  Column 6: Calculated based on data in columns ...
#
#     Human Development Index (HDI)  Life expectancy at birth  \
# 0                            Value                  (years)
# ...

# %%
# Out:
#   File "<ipython-input-26-ba5870b1a0ea>", line 1
#     df=df.loc(:,[1,2,3])
#               ^
# SyntaxError: invalid syntax
