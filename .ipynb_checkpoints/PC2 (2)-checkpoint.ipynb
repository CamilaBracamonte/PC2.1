# %% [markdown]
# ## PRACTICA CALIFICADA 2
# Camila Bracamonte - 20223376

# %% [markdown]
# **1. Cargo mi DATA**

# %%
import pandas as pd
df=pd.read_excel('https://github.com/CamilaBracamonte/PC2.1/blob/main/HDI%20(4).xlsx?raw=true',header=4)
df
# Out:
#     Unnamed: 0                                         Unnamed: 1  \
# 0     HDI rank                                            Country
# 1          NaN                                                NaN
# 2          NaN                        VERY HIGH HUMAN DEVELOPMENT
# 3            1                                        Switzerland
# 4            2                                             Norway
# ..         ...                                                ...
# 267        NaN                          Column 2: UNDESA (2022a).
# 268        NaN  Column 3: CEDLAS and World Bank (2022), ICF Ma...
# 269        NaN  Column 4: Barro and Lee (2018), ICF Macro Demo...
# 270        NaN  Column 5: IMF (2022), UNDESA (2022b), United N...
# 271        NaN  Column 6: Calculated based on data in columns ...
#
#     Human Development Index (HDI)   Unnamed: 3 Life expectancy at birth  \
# 0                            Value         NaN                  (years)
# ...

# %% [markdown]
# **2. Me quedo con las columnas que no contienen N/A**

# %%
df2=df.iloc[:,[0,1,2,4,6,8,10,12,14]]
df2
# Out:
#     Unnamed: 0                                         Unnamed: 1  \
# 0     HDI rank                                            Country
# 1          NaN                                                NaN
# 2          NaN                        VERY HIGH HUMAN DEVELOPMENT
# 3            1                                        Switzerland
# 4            2                                             Norway
# ..         ...                                                ...
# 267        NaN                          Column 2: UNDESA (2022a).
# 268        NaN  Column 3: CEDLAS and World Bank (2022), ICF Ma...
# 269        NaN  Column 4: Barro and Lee (2018), ICF Macro Demo...
# 270        NaN  Column 5: IMF (2022), UNDESA (2022b), United N...
# 271        NaN  Column 6: Calculated based on data in columns ...
#
#     Human Development Index (HDI)  Life expectancy at birth  \
# 0                            Value                  (years)
# ...

# %% [markdown]
# **3. Me quedo con las filas necesarias y agrego una nueva columna**

# %%
df2=df2.iloc[0:197]
df2
# Out:
#     Unnamed: 0                   Unnamed: 1 Human Development Index (HDI)   \
# 0     HDI rank                      Country                          Value
# 1          NaN                          NaN                           2021
# 2          NaN  VERY HIGH HUMAN DEVELOPMENT                            NaN
# 3            1                  Switzerland                          0.962
# 4            2                       Norway                          0.961
# ..         ...                          ...                            ...
# 192        187                      Burundi                          0.426
# 193        188     Central African Republic                          0.404
# 194        189                        Niger                            0.4
# 195        190                         Chad                          0.394
# 196        191                  South Sudan                          0.385
#
#     Life expectancy at birth Expected years of schooling  \
# ...

# %%
df2=df2.drop(index=[0,1,2,69,119,164])
df2
# Out:
#     Unnamed: 0                Unnamed: 1 Human Development Index (HDI)   \
# 3            1               Switzerland                          0.962
# 4            2                    Norway                          0.961
# 5            3                   Iceland                          0.959
# 6            4    Hong Kong, China (SAR)                          0.952
# 7            5                 Australia                          0.951
# ..         ...                       ...                            ...
# 192        187                   Burundi                          0.426
# 193        188  Central African Republic                          0.404
# 194        189                     Niger                            0.4
# 195        190                      Chad                          0.394
# 196        191               South Sudan                          0.385
#
#     Life expectancy at birth Expected years of schooling  \
# ...

# %%
df2['rango Human Development'] = pd.cut(df2["Human Development Index (HDI) "], bins=[0,0.549, 0.699, 0.796,1], labels=['LOW', 'MEDIUM', 'HIGH', 'VERY HIGH'])
df2
# Out:
#     Unnamed: 0                Unnamed: 1 Human Development Index (HDI)   \
# 3            1               Switzerland                          0.962
# 4            2                    Norway                          0.961
# 5            3                   Iceland                          0.959
# 6            4    Hong Kong, China (SAR)                          0.952
# 7            5                 Australia                          0.951
# ..         ...                       ...                            ...
# 192        187                   Burundi                          0.426
# 193        188  Central African Republic                          0.404
# 194        189                     Niger                            0.4
# 195        190                      Chad                          0.394
# 196        191               South Sudan                          0.385
#
#     Life expectancy at birth Expected years of schooling  \
# ...

# %%
df2.rename({"Unnamed: 0": "HDI Rank", "Unnamed: 1": "Country","HDI rank":"HDI 2020 Rank"}, axis='columns')
# Out:
#     HDI Rank                   Country Human Development Index (HDI)   \
# 3          1               Switzerland                          0.962
# 4          2                    Norway                          0.961
# 5          3                   Iceland                          0.959
# 6          4    Hong Kong, China (SAR)                          0.952
# 7          5                 Australia                          0.951
# ..       ...                       ...                            ...
# 192      187                   Burundi                          0.426
# 193      188  Central African Republic                          0.404
# 194      189                     Niger                            0.4
# 195      190                      Chad                          0.394
# 196      191               South Sudan                          0.385
#
#     Life expectancy at birth Expected years of schooling  \
# 3                    83.9872                   16.500299
# ...

# %% [markdown]
# # Al final, me queda mi dataframe con la sigueinte infromación:
#
# 1.   HD1 Rank
# 2. Country
# 3.   Human Development Index (HDI)
# 4. Life expentancy at birth
# 5. Expected years of schooling
# 6. Mean years of schooling
# 7. Gross national income (GNI) per capita
# 8. GNI per capita rank minus HDI rank
# 9. HDI 2020 Rank
# 10. Rango Human Development
